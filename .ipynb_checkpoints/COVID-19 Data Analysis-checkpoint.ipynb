# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Get Data From CSV File
data=pd.read_csv("D:/Projects/Covid19/DataSet/covid_19_data.csv",parse_dates=['Last Update'])
# Rename Columns
data.rename(columns={'ObservationDate':'Date', 'Country/Region':'Country'}, inplace=True)
# Display Data
data.head()
# Out:
#    SNo        Date Province/State         Country         Last Update  \
# 0    1  01/22/2020          Anhui  Mainland China 2020-01-22 17:00:00
# 1    2  01/22/2020        Beijing  Mainland China 2020-01-22 17:00:00
# 2    3  01/22/2020      Chongqing  Mainland China 2020-01-22 17:00:00
# 3    4  01/22/2020         Fujian  Mainland China 2020-01-22 17:00:00
# 4    5  01/22/2020          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
data.shape
# Out:
# (7014, 8)

# %%
# Check for Data Types
data.dtypes
# Out:
# SNo                        int64
# Date                      object
# Province/State            object
# Country                   object
# Last Update       datetime64[ns]
# Confirmed                float64
# Deaths                   float64
# Recovered                float64
# dtype: object

# %%
# Check for Null Values
data.isnull().sum().to_frame('nulls')
# Out:
#                 nulls
# SNo                 0
# Date                0
# Province/State   2925
# Country             0
# Last Update         0
# Confirmed           0
# Deaths              0
# Recovered           0

# %%
# Refrences=(Keggale - https://www.kaggle.com/abdulrhmanalosman/covid-19-analysis-visualization-prediction)

dataFrame = data.groupby(["Date", "Country"])[['Date', 'Country', 'Confirmed', 'Deaths', 'Recovered']].sum().reset_index()
# Get All the Confiremd Cases all arounfd the world
Confirmed_patients=dataFrame.sort_values('Confirmed',ascending=False)
Confirmed_patients=Confirmed_patients.drop_duplicates('Country')

world_Total_Confirmed=Confirmed_patients['Confirmed'].sum()  #Total Confirmed Patients
world_Total_Deaths=Confirmed_patients['Deaths'].sum()        #Total Deaths
world_Total_Recovered=Confirmed_patients['Recovered'].sum()  #Total Recovered Patients
 
world_Deaths_Rate=(world_Deaths_Total*100)/world_Confirmed_Total           #Get Death Precentage of the World
world_Recovered_rate=(world_Recovered_Total*100)/world_Confirmed_Total    #Get Recovered Precentage in the World

China=Confirmed_patients[Confirmed_patients['Country']=='Mainland China']        #Get Confirmed Patients precentage in china
China_Recovered_rate=(int(China['Recovered'].values)*100)/int(China['Confirmed'].values)  #Get Recovered Patients precentage in china

Italy=Confirmed_patients[Confirmed_patients['Country']=='Italy']        #Get confirmed Patients Precentage in Italy
Italy_Recovered_rate=(int(Italy['Recovered'].values)*100)/int(Italy['Confirmed'].values)  #GEt Recovered Patients Precentage in Italy 

SriLanka=Confirmed_patients[Confirmed_patients['Country']=='Sri Lanka']        #Get Confirmed Patients Percentage in sri lanka
SriLanka_Recovered_rate=(int(SriLanka['Recovered'].values)*100)/int(SriLanka['Confirmed'].values)  #Get Recovered patients Precentage in Sri Lanka

#Add Values to the Table and Display Table
Table={'Total Confirmed Patients in the World : ':world_Total_Confirmed,'Total Deaths Confirmed in the world : ':world_Total_Deaths,'Total Recovered Patients in the world : ':world_Total_Recovered,'Rate of Recovered Patients(Precentage) :':world_Recovered_rate,'Rate of Death Patients(Precentage) :':world_Deaths_Rate,
      'Rate of Recovered China cases(Presentage) :':China_Recovered_rate,'Rate of Recovers Italy Cases(Precentage) : ':Italy_Recovered_rate,'Rate of Recovers in Sri Lankan Cases(Precentage) : ':SriLanka_Recovered_rate}
Table=pd.DataFrame.from_dict(Table,orient='index',columns=['Total'])

Table.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row1_col0 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row2_col0 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row3_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row4_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row5_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row6_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row7_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row0" class="row_heading level0 row0" >Total Confirmed Patients in the World : </th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row0_col0" class="data row0 col0" >242810.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row1" class="row_heading level0 row1" >Total Deaths Confirmed in the world : </th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row1_col0" class="data row1 col0" >9866.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row2" class="row_heading level0 row2" >Total Recovered Patients in the world : </th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row2_col0" class="data row2 col0" >84963.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row3" class="row_heading level0 row3" >Rate of Recovered Patients(Precentage) :</th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row3_col0" class="data row3 col0" >34.991557</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row4" class="row_heading level0 row4" >Rate of Death Patients(Precentage) :</th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row4_col0" class="data row4 col0" >4.063259</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row5" class="row_heading level0 row5" >Rate of Recovered China cases(Presentage) :</th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row5_col0" class="data row5 col0" >87.024749</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row6" class="row_heading level0 row6" >Rate of Recovers Italy Cases(Precentage) : </th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row6_col0" class="data row6 col0" >10.820032</td>
#             </tr>
#             <tr>
#                         <th id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1level0_row7" class="row_heading level0 row7" >Rate of Recovers in Sri Lankan Cases(Precentage) : </th>
#                         <td id="T_f18871ca_6b30_11ea_89e4_7c2a3182fda1row7_col0" class="data row7 col0" >5.000000</td>
#             </tr>
#     </tbody></table>

# %%
# Display Total Confirmed Patients/Deaths and Recovered
Graph=Table.head(3)
x=Graph.index
y=Graph['Total'].values
plt.rcParams['figure.figsize'] = (11,6)
sns.barplot(x,y,order=x ).set_title('Covid 19 Data Analysis')
# Out:
# Text(0.5, 1.0, 'Covid 19 Data Analysis')

# %%
Recovered_rate=(Confirmed_patients['Recovered']*100)/Confirmed_patients['Confirmed']  #Get Recovered Precentage
Deaths_rate=(Confirmed_patients['Deaths']*100)/Confirmed_patients['Confirmed']  #Get Death Precentage
cases_rate=(Confirmed_patients.Confirmed*100)/world_Total_Confirmed    #Get Total Patients Confirmed

#Set Rated to the Table
Confirmed_patients['Recovered Patients Rate']=pd.DataFrame(Recovered_rate)  
Confirmed_patients['Deaths Patients Rate']=pd.DataFrame(Deaths_rate)
Confirmed_patients['Total Patients Rate']=pd.DataFrame(cases_rate)

# Display Table
Confirmed_patients.head(100).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row0_col3 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row0_col6 {
#             background-color:  #99c7e0;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row0_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row1_col2 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row1_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row1_col4 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row1_col5 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row1_col6 {
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row1_col7 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row2_col2 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row2_col3 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row2_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row2_col5 {
#             background-color:  #a4cce3;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row2_col6 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row2_col7 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row3_col2 {
#             background-color:  #ccdff1;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row3_col3 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row3_col4 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row3_col5 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row3_col6 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row3_col7 {
#             background-color:  #ccdff1;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row4_col2 {
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row4_col3 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row4_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row4_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row4_col6 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row4_col7 {
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row5_col2 {
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row5_col3 {
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row5_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row5_col5 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row5_col6 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row5_col7 {
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row6_col2 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row6_col3 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row6_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row6_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row6_col6 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row6_col7 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row7_col2 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row7_col3 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row7_col4 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row7_col5 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row7_col6 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row7_col7 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row8_col2 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row8_col3 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row8_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row8_col5 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row8_col6 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row8_col7 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row9_col2 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row9_col3 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row9_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row9_col5 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row9_col6 {
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }    #T_f1be885c_6b30_11ea_8b49_7c2a3182fda1row9_col7 {
#             background-color:  #f1f7fd;
#             color:  #000000;

# %%
# Function for get Each Contry's Covid-19 Active and confirmed and recoverd cases

def casesInEachCountry(country):
    data_of_country = data[data['Country']==country]  #Get Data of the given Country
    table = data_of_country.drop(['SNo','Province/State','Last Update'], axis=1)  #Drop unwanted Columns
    table['ActiveCases'] = table['Confirmed'] - table['Recovered'] - table['Deaths']  #Calculate Active Cases in the country
#     Display ActiveCases , Confiremd,recovered and Deaths in each country
    graph = pd.pivot_table(table, values=['ActiveCases','Confirmed', 'Recovered','Deaths'],index=['Date'], aggfunc=np.sum)

    x_coordinates = [1,60]
    y_coordinates = [1, 1]
    
    return  graph.plot(), plt.plot(x_coordinates, y_coordinates)

# %%
casesInEachCountry('Mainland China')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x262ed8117b8>,
#  [<matplotlib.lines.Line2D at 0x262ed86f978>])

# %%
 casesInEachCountry('Italy')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x262ed7be6d8>,
#  [<matplotlib.lines.Line2D at 0x262ed9356a0>])

# %%
 casesInEachCountry('Sri Lanka')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x262ed782828>,
#  [<matplotlib.lines.Line2D at 0x262ed7be940>])

# %%
casesInEachCountry('Iran')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x262ec72af60>,
#  [<matplotlib.lines.Line2D at 0x262ec5ca3c8>])
